# %% [markdown]
# <a href="https://colab.research.google.com/github/KimNamHo2020/OpenCV-ss/blob/main/3CH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: from google.colab import drive
# import cv2
# from google.colab.patches import cv2_imshow
# import numpy as np
# import matplotlib.pyplot as plt

from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# RGB 형식으로 변환

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/Copy of leng2.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %% [markdown]
# 흑백형식으로 변환

# %%
Gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(Gray_img.shape)
plt.imshow(Gray_img, cmap='gray')
# Out:
# (512, 512)

# %%
cv2_imshow(Gray_img)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %% [markdown]
# 이미지 크기 조정

# %%
mimg=cv2.resize(Gray_img, dsize =(256*4, 256*4))
plt.imshow(mimg, cmap = 'gray')

# %%
cv2_imshow(mimg)
# Out:
# <PIL.Image.Image image mode=L size=1024x1024>

# %% [markdown]
# 특정 영역 픽셀 조작

# %%
for h in range(100,150):
  for w in range(100,150):
    Gray_img[h,w] = 0
plt.imshow(Gray_img, cmap='gray')

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/Copy of girl.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
plt.imshow(gimg, cmap='gray')
# Out:
# (256, 256)

# %%
gPlus = np.zeros((gimg.shape[0], gimg.shape[1]), dtype = np.ubyte)

# %% [markdown]
# 밝기 조정

# %%
val = 100

for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    plusVal = gimg[h,w] + val
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

plt.imshow(gPlus, cmap = 'gray')

# %% [markdown]
# 두번째 이미지 읽기 및 흑백 변환

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/aero2.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256)

# %% [markdown]
# 세 번째 이미지 읽기 및 흑백 변환

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/aero2.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256)

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gimg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg1.shape)
plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256)

# %% [markdown]
# 이미지 혼합

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/lena256.jpg')
gimg2 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
#plt.imshow(gimg, cmap='gray')
cv2_imshow(gimg2)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
weight = 0.2

for h in range(gimg1.shape[0]):
  for w in range(gimg1.shape[1]):
    plusVal = np.int32(gimg1[h,w])*weight + np.int32(gimg2[h,w])*(1-weight)
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

cv2_imshow(gPlus)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

gImg1 = cv2.cvtColor(RGB_img, cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')
# Out:
# (256, 256)

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/Copy of circle.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

gImg2 = cv2.cvtColor(RGB_img, cv2.COLOR_BGR2GRAY)
print(gImg2.shape)
plt.imshow(gImg2, cmap='gray')
# Out:
# (286, 322)

# %% [markdown]
# 비트 연산을 위한 준비

# %%
gBit=np.zeros((gImg1.shape[0],gImg1.shape[1]),dtype=np.ubyte)

# %% [markdown]
# 비트 연산 수행

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
   # bitval=gImg1[h,w]& gImg2[h,w]
   # bitval=gImg1[h,w]|gImg2[h,w]
    bitval=gImg1[h,w]^gImg2[h,w]


    gBit[h,w]=bitval

cv2_imshow(gBit)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

gImg1 = cv2.cvtColor(RGB_img, cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')
# Out:
# (256, 256)

# %% [markdown]
# 픽셀 값 변환

# %%
gOutImg= np.zeros((gImg1.shape[0],gImg1.shape[1]))

# %%
for h in range(0,gImg1.shape[0]):
  for w in range(0,gImg1.shape[1]):
    val = gImg1[h,w] % 64
    val=val*4
    gOutImg[h,w] = val

plt.imshow(gOutImg,cmap='gray')

# %%
equalval =200
width =5


min = equalval -width
max = equalval +width

# %%
for h in range(0,gImg1.shape[0]):
  for w in range(0,gImg1.shape[1]):
    val = 255*(gImg1[h,w]/128-1)**2
    gOutImg[h,w] = val
cv2_imshow(gOutImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# 비트 평면 추출

# %%
planeNumber =1
planeValue = 1

for i in range(planeNumber-1):
  planeValue= planeValue *2

# %%
for h in range(0,gImg1.shape[0]):
  for w in range(0,gImg1.shape[1]):
    imval= (int)(gImg1[h,w] / planeValue)
    if(imval %2 == 0):
      gOutImg[h,w] = 0
    else:
      gOutImg[h,w] = 255
cv2_imshow(gOutImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/디지털영상처리/Copy of circle.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

gImg2 = cv2.cvtColor(RGB_img, cv2.COLOR_BGR2GRAY)
print(gImg2.shape)
plt.imshow(gImg2, cmap='gray')
# Out:
# (286, 322)

# %% [markdown]
# 워터마킹

# %%
gWaterMaker = gImg1.copy()

for h in range(0,gImg1.shape[0]):
  for w in range(0,gImg1.shape[1]):
    imVal = gImg2[h,w]
    if(imval>128):
      if(gImg1[h,w] % 2 == 0 ):
        gWaterMaker[h,w] += 1
    else:
      if(gImg1[h,w] % 2 == 1 ):
        gWaterMaker[h,w] -= 1
cv2_imshow(gWaterMaker)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# 코드의 비트 평면 준비

# %%
planeNumber =1
planeValue = 1

for i in range(planeNumber-1):
  planeValue= planeValue *2
