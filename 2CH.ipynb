# %% [markdown]
# <a href="https://colab.research.google.com/github/KimNamHo2020/OpenCV-ss/blob/main/2CH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/MyDrive/ColabP/ch01/강아지 사진.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=436x601>

# %%
print(img.shape)
# Out:
# (601, 436, 3)

# %% [markdown]
# 이미지 색상형식 변경

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
img = cv2.imread('/content/gdrive/MyDrive/ColabP/ch01/강아지 사진.png')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(RGB_img)
# Out:
# <PIL.Image.Image image mode=RGB size=436x601>

# %%
print(RGB_img.shape);
# Out:
# (601, 436, 3)

# %% [markdown]
# RGB 채널 분리

# %%
cv2.split(RGB_img);
